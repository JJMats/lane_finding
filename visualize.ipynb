# %%
import filters, helpers, lane_finding, line, camera
import os, glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# C:\Users\Jeremy\Anaconda3\envs\lane_finding\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
# Create an instance of a camera and calibrate it
cam = camera.Camera()
cal_images_dir = "images/camera_cal/calibration*"
cam.calibrate(cal_images_dir)

# %%
# Grab an image and undistort it
camera_cal_img_files = glob.glob("images/camera_cal/calibration*")
test_img = mpimg.imread(camera_cal_img_files[11])
undst_img = cam.undistort(test_img)
plt.imshow(undst_img)

# %%
# Test Sobel edge detection filter
binary_test_image = filters.abs_sobel_thresh(test_img, 'y', 3, (20, 100))
plt.imshow(binary_test_image)

# %%
# Import test images
test_images = glob.glob("images/test_images/*")
test_image = mpimg.imread(test_images[0])

# Run an image through the pipeline to draw the detected lane on it
left_lane_line = line.Line()
right_lane_line = line.Line()
lane_img = lane_finding.find_lane(cam, test_image)
plt.imshow(lane_img)
