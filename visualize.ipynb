# %%
import filter, helpers, lane_finding, line, camera
import os, glob
#import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#import cv2
# %matplotlib inline
# Out:
# C:\Users\Jeremy\Anaconda3\envs\lane_finding\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
cam = camera.Camera()
cal_images_dir = "images/camera_cal/calibration*"
cam.calibrate(cal_images_dir)

# %%
camera_cal_img_files = glob.glob("images/camera_cal/calibration*")
test_img = mpimg.imread(camera_cal_img_files[11])
undst_img = cam.undistort(test_img)
plt.imshow(undst_img)

# %%
print(cam.img_points)
